# %% [markdown]
# # YouTube Video downloader
#
# ## what is Youtube?
# - YouTube is a popular video-sharing platform that helps users to watch, like, comment and upload any videos. You can access the video from desktop PCs, tablets, mobile phones, and laptops.
#
# ![youtube%20pic.png](attachment:youtube%20pic.png)
#
# ## What is youtube video downloader?
# - You can use YouTube video downloaders to download videos in numerous formats, including MP3 and MP4. These are easy to use apps that support a high and low quality resolution that matches with your system needs.

# %% [markdown]
# ## Problem statement:
# - A Python program to open a window where we can enter/copy-paste a youtube video link and click the download button to download the video directly to our system targeted directory.
#
# ## Problem Solving:
# - The first step is to import pytube and tkinter package.
#     - **import pytube**
#     - **from tkinter import ***
#
# -	Firstly, we have to create a window where we can add text boxes,buttons etc.
#     - **root = Tk()**
#     - Here write the code for buttons, label,entry box etc.
#     - **root.mainloop()**
#
# - For adding a label at the top which has texts can be achieved using the Label function.Inside this function, we can pass various parameter which can be used to change the design of text. Now place this label in the window using place() and x,y coordinates.
#    - **Label = Label(root,text="Enter your text", font=("bold",20))**
#    - **Label.place(x=120,y=20)**
#
# - Now to put an entry box where the user can put youtube video links.For that purpose, first create a variable that can hold the data entered, then by using Entry() to create an entry box, pass parameters like a variable, width, height, etc inside the Entry(). Finally place this entry box in the window using place() and x,y coordinates.
#    - **mylink = StringVar()**
#    - **pastelink = Entry(root, width=60, textvariable=mylink)**
#    - **pastelink.place(x=140, y=80)**
#
# - Now create a button to make the video download on the local machine.Button function requires text (to be displayed on it), color, width to change it, and the main parameter is to pass a function which has to be perform the action(download) as soon as the button is clicked.
#    - **B1 = Button(root,text="Download Video", width=20, bg='green',fg="white", command=downloadVideo)**
#    - **B1.place(x=220, y=110)**
#
# - The GUI is completed.
#
# - Lets start with what will happen when the button is clicked that is to write the code inside the function(defining the functions).First, get the link from the entry box.
#    - **x = str(mylink.get())**
#
# - Then using the YouTube() we can get the video from youtube itself the main thing to change here is to change the file extension whatever we want.
#    - **ytvideo = YouTube(x).streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()**
#
# - Finally, download the youtube video using video function to the required directory folder.
#    - **ytvideo.download('C:\Users\folder')**

# %% [markdown]
# ## Examples of Youtube video downloaders available:
# - Itubego
# - By Click Downloader
# - 4K Video Downloader
# - SnapDownloader

# %% [markdown]
# ## What is a GUI?
# - The graphical user interface is a form of user interface that allows users to interact with electronic devices through graphical icons and audio indicator such as primary notation, instead of text-based user interfaces, typed command labels or text navigation.
# ![guiex.png](attachment:guiex.png)

# %% [markdown]
# ## Tkinter GUI:
# - Tkinter is the standard GUI library for Python. Python when combined with Tkinter provides a fast and easy way to create GUI applications. Tkinter provides a powerful object-oriented interface to the Tk GUI toolkit. Creating a GUI application using Tkinter is an easy task.
# ![root-window-python.png](attachment:root-window-python.png)

# %% [markdown]
# # YouTube Video Downloader final GUI

# %% [markdown]
# ![Output.png](attachment:Output.png)
